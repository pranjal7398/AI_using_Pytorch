# %% [markdown]
# <a href="https://colab.research.google.com/github/pranjal7398/AI_using_Pytorch/blob/main/geminiAPI_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
from google.colab import userdata
from google import genai

GEMINI_API_KEY = userdata.get("GEMINI_API_KEY")

client = genai.Client(api_key=GEMINI_API_KEY)

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents= input("Enter what you want to search :- ")
)

print(response.text)
# Out:
# Enter what you want to searchMachine learning under 100 words
# **Machine Learning (ML)** is a branch of artificial intelligence where algorithms learn from data to make predictions or decisions without being explicitly programmed. By identifying patterns in large datasets, ML models automatically improve their accuracy over time.
#
# Key approaches include:
# * **Supervised Learning:** Trains on labeled data (e.g., identifying spam emails).
# * **Unsupervised Learning:** Finds hidden patterns in unlabeled data (e.g., grouping customer demographics).
# * **Reinforcement Learning:** Learns through trial and error using rewards (e.g., mastering chess).
#
# ML powers everyday technologies like recommendation systems, voice assistants, fraud detection, and self-driving cars.
